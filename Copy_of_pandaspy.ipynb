# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravigupta9565/Ravi-gupta/blob/main/Copy_of_pandaspy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas

# %%
import pandas as pd

# %%
from google.colab import files
data  = files.upload()

# %%
data

# %%
ravi=pd.read_csv("/content/sales_data_noisy.csv")
print(ravi)

# %%
ravi.head()

# %%
ravi.tail()

# %%
ravi.sample()

# %%
ravi.info()

# %%
ravi.dtypes

# %%
ravi.describe()

# %%
ravi.ndim

# %%
ravi['Category'].unique()

# %%
ravi['Category'].nunique()

# %%
ravi.isnull()

# %%
ravi.isnull().sum()

# %%
ravi.fillna(31)

# %%
ravi['Quantity']

# %%
ravi.shape

# %%
ravi[['Category','Quantity']]

# %%
ravi.sort_values('CustomerID')

# %%
s=ravi['Price']
s

# %%
s.clip(lower=50,upper=100)
